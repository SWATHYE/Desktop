# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Documents/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
# [1000 rows x 8 columns]

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1000.000000    1000.000000    1000.000000
# mean     66.001000      69.195000      68.119000
# std      15.569567      14.706436      15.226381
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.250000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# # 1. Find out how many males and females participated in the test.

# %%
df['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2. What do you think about the students' parental level of education?

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df['total marks']=((df['math score']+df['reading score']+df['writing score']))
df.head(2)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group C            some high school  free/reduced
# 1  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none           0             17             10
# 1                    none           8             24             23
#
#    total marks
# 0           27
# 1           55

# %%
df.groupby(['parental level of education','total marks']).size()
# Out:
# parental level of education  total marks
# associate's degree           95             1
#                              119            1
#                              123            1
#                              130            1
#                              131            1
#                                            ..
# some high school             267            2
#                              270            1
#                              274            1
#                              289            1
#                              297            1
# Length: 593, dtype: int64

# %%
df['total marks'].mean()
# Out:
# 203.315

# %%
plt.figure(figsize=(5,5))
sns.barplot(df['parental level of education'],df['total marks'])
plt.xticks(rotation=20)
plt.ylim(0,300)
plt.axhline(y = 203.312, color = 'r', linestyle = 'dashed', label = "Mean value line")
plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper center')
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # 3. Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
plt.figure(figsize=(15,5))

plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=1.0,wspace=0.8, hspace=0.2)

plt.subplot(131)

plt.title('Math Scores')

sns.barplot(hue="gender", y="math score", x="test preparation course", data=df)
plt.axhline(y = 66.067, color = 'r', linestyle = 'dashed', label = "avg math score")
plt.legend(bbox_to_anchor = (1.3, 1), loc = 'upper center')


plt.subplot(132)

plt.title('Reading Scores')
sns.barplot (hue="gender", y="reading score", x="test preparation course", data=df)
plt.axhline(y = 69.117, color = 'g', linestyle = '-', label = "avg reading score")
plt.legend(bbox_to_anchor = (1.3, 1), loc = 'upper center')

plt.subplot(133)

plt.title('Writing Scores')
sns.barplot (hue="gender", y="writing score", x="test preparation course", data=df)
plt.axhline(y = 67.997, color = 'b', linestyle = ':', label = "avg writing score")
plt.legend(bbox_to_anchor = (1.4, 1), loc = 'upper center')

# %% [markdown]
# # 4. What do you think about the scoring variation for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
plt.figure(figsize=(15,5))

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='math score', data=df, kde=True, hue='gender')
plt.title('math scores of groups')
plt.show()

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='reading score', data=df, kde=True, hue='gender')
plt.title('reading scores of groups')
plt.show()

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='writing score', data=df, kde=True, hue='gender')
plt.title('math scores of groups')
plt.show()

# %%
plt.figure(figsize=(15,5))

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='math score', data=df, kde=True, hue='test preparation course')
plt.title('math scores of groups')
plt.show()

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='reading score', data=df, kde=True, hue='test preparation course')
plt.title('reading scores of groups')
plt.show()

sns.set_palette('bright') 
plt.figure(figsize=(15,6))
sns.histplot(x='writing score', data=df, kde=True, hue='test preparation course')
plt.title('math scores of groups')
plt.show()

# %% [markdown]
# # 5. The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management
# #to achieve this.

# %%
df.describe()
# Out:
#         math score  reading score  writing score  total marks
# count  1000.000000    1000.000000    1000.000000  1000.000000
# mean     66.001000      69.195000      68.119000   203.315000
# std      15.569567      14.706436      15.226381    43.227009
# min       0.000000      17.000000      10.000000    27.000000
# 25%      57.000000      59.000000      58.000000   175.000000
# 50%      66.000000      70.000000      69.000000   206.000000
# 75%      77.000000      79.250000      79.000000   233.250000
# max     100.000000     100.000000     100.000000   300.000000

# %%
np.percentile(df['math score'], 75)
# Out:
# 77.0

# %%
a=df[df['math score']>=77.0].groupby(['gender','race/ethnicity','parental level of education','test preparation course','math score']).size().reset_index()
a
# Out:
#      gender race/ethnicity parental level of education  \
# 0    female        group A          associate's degree
# 1    female        group A                 high school
# 2    female        group A                some college
# 3    female        group A            some high school
# 4    female        group A            some high school
# ..      ...            ...                         ...
# 232    male        group E            some high school
# 233    male        group E            some high school
# 234    male        group E            some high school
# 235    male        group E            some high school
# 236    male        group E            some high school
#
#     test preparation course  math score  0
# 0                      none          82  1
# 1                 completed          77  1
# 2                 completed          78  1
# 3                 completed          85  1
# 4                 completed          92  1
# ..                      ...         ... ..
# 232               completed          87  1
# 233               completed          89  1
# 234                    none          82  1
# 235                    none          92  1
# 236                    none          94  1
#
# [237 rows x 6 columns]

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       237 non-null    object
#  1   race/ethnicity               237 non-null    object
#  2   parental level of education  237 non-null    object
#  3   test preparation course      237 non-null    object
#  4   math score                   237 non-null    int64
#  5   0                            237 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 11.2+ KB

# %%
a['gender'].value_counts()
# Out:
# male      140
# female     97
# Name: gender, dtype: int64
